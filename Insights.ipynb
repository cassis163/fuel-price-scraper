# %%
import sys

# !{sys.executable} -m pip install pandas matplotlib datetime
# Out:
# ...
#      |████████████████████████████████| 51 kB 636 kB/s eta 0:00:011
# ...
#      |████████████████████████████████| 255 kB 4.0 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

file_name = 'data.csv'
df = pd.read_csv(file_name, index_col='timestamp')

df
# Out:
# 6

# %%
from datetime import datetime

def plot_per_day():
    plt.xticks(rotation=45)
    df.plot()
    
plot_per_day()
